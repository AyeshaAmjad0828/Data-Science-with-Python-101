# %% [markdown]
# #Pandas

# %% [markdown]
# Task# 1
#
# a. Import pandas library
#
# b. Read csv data from "https://raw.githubusercontent.com/Masadn/PythonCourse/master/dataset/mlbData.csv")

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##MLB data

# %%
mlb = pd.read_csv("https://raw.githubusercontent.com/Masadn/PythonCourse/master/dataset/mlbData.csv")

# %%
mlb.head(5)
# Out:
#    Height  Weight    Age
# 0      74     180  22.99
# 1      74     215  34.69
# 2      72     210  30.78
# 3      72     210  35.43
# 4      73     188  35.71

# %%
mlb.dtypes
# Out:
# Height      int64
# Weight      int64
# Age       float64
# dtype: object

# %%
mlb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Height  1015 non-null   int64
#  1   Weight  1015 non-null   int64
#  2   Age     1015 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 23.9 KB

# %%
mlb.Height
# Out:
# 0       74
# 1       74
# 2       72
# 3       72
# 4       73
#         ..
# 1010    73
# 1011    74
# 1012    75
# 1013    75
# 1014    73
# Name: Height, Length: 1015, dtype: int64

# %% [markdown]
# Task# 2
#
# Convert the units of height and weight to metric (meters and kilograms respectively).

# %%
np_mlb = np.array(mlb)

# %%
conversion=np.array([0.0254,0.453592,1])
print(np_baseball*conversion)

# %% [markdown]
# Task# 2
#
# a. Read csv data from a local folder.
#
# b. Read excel data from a local folder.

# %% [markdown]
# ##Advertising Data

# %% [markdown]
# df = pd.read_csv(r"C:/Users/zaina/OneDrive/Desktop/Advertising.csv")

# %%
advertising=pd.read_csv('/content/sample_data/Advertising.csv')
advertising
# Out:
#      TV(millionUSD)  SocialMedia(millionUSD)  newspaper(millionUSD)  \
# 0        230.100000                37.800000              69.200000
# 1         44.500000                39.300000              45.100000
# 2         17.200000                45.900000              69.300000
# 3        151.500000                41.300000              58.500000
# 4        180.800000                10.800000              58.400000
# ..              ...                      ...                    ...
# 147      243.200000                49.000000              44.300000
# 148       38.000000                40.300000              11.900000
# 149      144.151007                24.568456              32.297987
# 150      139.200000                26.700000              28.900000
# 151       85.656315                14.751463              22.402096
#
#      sales(millionUSD)         Unnamed: 4
# 0            22.100000                NaN
# 1            10.400000                NaN
# 2             9.300000                NaN
# 3            18.500000                NaN
# 4            12.900000                NaN
# ..                 ...                ...
# 147          25.400000                NaN
# 148          10.900000                NaN
# 149          14.177852               Mean
# 150          13.200000             Median
# 151           5.248328  StandardDeviation
#
# [152 rows x 5 columns]

# %% [markdown]
# Task# 3
#
# a. Print shape and columns of advertising data.
#
# b. Print all information on advertising data.

# %%
print(advertising.shape)
# Out:
# (152, 5)

# %%
print(advertising.columns)
# Out:
# Index(['TV(millionUSD)', 'SocialMedia(millionUSD)', 'newspaper(millionUSD)',
#        'sales(millionUSD)', 'Unnamed: 4'],
#       dtype='object')

# %%
#b. Print all information on advertising data.
print(advertising.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TV(millionUSD)           152 non-null    float64
#  1   SocialMedia(millionUSD)  152 non-null    float64
#  2   newspaper(millionUSD)    152 non-null    float64
#  3   sales(millionUSD)        152 non-null    float64
#  4   Unnamed: 4               3 non-null      object
# dtypes: float64(4), object(1)
# memory usage: 6.1+ KB
# None

# %%
advertising.dtypes
# Out:
# TV(millionUSD)             float64
# SocialMedia(millionUSD)    float64
# newspaper(millionUSD)      float64
# sales(millionUSD)          float64
# Unnamed: 4                  object
# dtype: object

# %% [markdown]
# Task# 4
#
# a. Print sales(millionUSD) field only.
#
# b. Create a subset that contains SocialMedia(millionUSD), sales(millionUSD), newspaper(millionUSD) fields.

# %%
advertising['sales(millionUSD)']
# Out:
# 0      22.100000
# 1      10.400000
# 2       9.300000
# 3      18.500000
# 4      12.900000
#          ...
# 147    25.400000
# 148    10.900000
# 149    14.177852
# 150    13.200000
# 151     5.248328
# Name: sales(millionUSD), Length: 152, dtype: float64

# %%
subset = advertising[['SocialMedia(millionUSD)','sales(millionUSD)', 'newspaper(millionUSD)']]
subset
# Out:
#      SocialMedia(millionUSD)  sales(millionUSD)  newspaper(millionUSD)
# 0                  37.800000          22.100000              69.200000
# 1                  39.300000          10.400000              45.100000
# 2                  45.900000           9.300000              69.300000
# 3                  41.300000          18.500000              58.500000
# 4                  10.800000          12.900000              58.400000
# ..                       ...                ...                    ...
# 147                49.000000          25.400000              44.300000
# 148                40.300000          10.900000              11.900000
# 149                24.568456          14.177852              32.297987
# 150                26.700000          13.200000              28.900000
# 151                14.751463           5.248328              22.402096
#
# [152 rows x 3 columns]

# %% [markdown]
# Task# 5
#
# a. Apply a filter condition to filter out less than 9 million USD sales. Print a boolean index series.
#
# b. Return complete advertising dataframe with this filter condition applied.

# %%
less_9million_sales = advertising['sales(millionUSD)'] < 9.00
less_9million_sales
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 147    False
# 148    False
# 149    False
# 150    False
# 151     True
# Name: sales(millionUSD), Length: 152, dtype: bool

# %%
less_9million_sales = advertising[advertising['sales(millionUSD)'] < 9.00]
less_9million_sales.head()
# Out:
#     TV(millionUSD)  SocialMedia(millionUSD)  newspaper(millionUSD)  \
# 5              8.7                     48.9                   75.0
# 8              8.6                      2.1                    1.0
# 10            66.1                      5.8                   24.2
# 22            13.2                     15.9                   49.6
# 44            25.1                     25.7                   43.3
#
#     sales(millionUSD) Unnamed: 4
# 5                 7.2        NaN
# 8                 4.8        NaN
# 10                8.6        NaN
# 22                5.6        NaN
# 44                8.5        NaN

# %% [markdown]
# Task# 6
#
# a. Read data from CAR DETAILS.csv and load it into a pandas dataframe.
#
# b. Filter out the data to only display cars with fuel type petrol.
#
# c. Filter out the data to only display cars with fuel type petrol and Diesel.

# %%
car = pd.read_csv('/content/sample_data/CAR DETAILS.csv')
car
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 2            600000     100000  Diesel  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 4            450000     141000  Diesel  Individual       Manual  Second Owner
# ...             ...        ...     ...         ...          ...           ...
# 4335         409999      80000  Diesel  Individual       Manual  Second Owner
# 4336         409999      80000  Diesel  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4338         865000      90000  Diesel  Individual       Manual   First Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
# [4340 rows x 6 columns]

# %%
car_fuel_petrol = car[car['fuel']=='Petrol']
car_fuel_petrol
# Out:
#       selling_price  km_driven    fuel seller_type transmission         owner
# 0             60000      70000  Petrol  Individual       Manual   First Owner
# 1            135000      50000  Petrol  Individual       Manual   First Owner
# 3            250000      46000  Petrol  Individual       Manual   First Owner
# 5            140000     125000  Petrol  Individual       Manual   First Owner
# 6            550000      25000  Petrol  Individual       Manual   First Owner
# ...             ...        ...     ...         ...          ...           ...
# 4326          65000     150000  Petrol  Individual       Manual   Third Owner
# 4327         190000      60000  Petrol  Individual       Manual  Second Owner
# 4329         160000      60000  Petrol  Individual       Manual  Second Owner
# 4337         110000      83000  Petrol  Individual       Manual  Second Owner
# 4339         225000      40000  Petrol  Individual       Manual   First Owner
#
# [2123 rows x 6 columns]

# %%
car_fuel_petrol_diesel = car[car['fuel'].isin(['Petrol', 'Diesel'])]
car_fuel_petrol_diesel
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 car_fuel_petrol_diesel = car[car['fuel'].isin(['Petrol', 'Diesel'])]
#       2 car_fuel_petrol_diesel
#
# NameError: name 'car' is not defined

# %%
car.describe(include='all')
# Out:
#         selling_price      km_driven    fuel seller_type transmission  \
# count    4.340000e+03    4340.000000    4340        4340         4340
# unique            NaN            NaN       5           3            2
# top               NaN            NaN  Diesel  Individual       Manual
# freq              NaN            NaN    2153        3244         3892
# mean     5.041273e+05   66215.777419     NaN         NaN          NaN
# std      5.785487e+05   46644.102194     NaN         NaN          NaN
# min      2.000000e+04       1.000000     NaN         NaN          NaN
# 25%      2.087498e+05   35000.000000     NaN         NaN          NaN
# 50%      3.500000e+05   60000.000000     NaN         NaN          NaN
# 75%      6.000000e+05   90000.000000     NaN         NaN          NaN
# max      8.900000e+06  806599.000000     NaN         NaN          NaN
#
#               owner
# count          4340
# unique            5
# top     First Owner
# freq           2832
# mean            NaN
# std             NaN
# min             NaN
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max             NaN
