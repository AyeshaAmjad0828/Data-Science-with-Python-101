# %% [markdown]
# #Simple Data Cleaning
#
# Data cleaning is the most crucial step in any project, if we do not take care of it properly, it might lead us to a completely different conclusion. Often than not, we might spend half of the time cleaning our data in most projects.
#
# In this notebook, we will discuss some Python functions that can help us in data cleaning especially in:
#
# - Dropping unused column
# - Removing duplicate
# - Mapping of Data
# - Dealing with null data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###Task# 1
#
# a. Import pandas and numpy
#
# b. Read data from titanic.csv into a python dataframe
#
# c. Preview the first 5 records
#
# d. Display the metadata of titanic.csv

# %%
titanic = pd.read_csv('/content/sample_data/titanic_data.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   -      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  na      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    Parch            Ticket     Fare Cabin Embarked          OnboardTime  \
# 0      0         A/5 21171   7.2500   NaN        S  1912-04-10 09:42:47
# 1      0          PC 17599  71.2833   C85        C  1912-04-10 09:54:01
# 2      0  STON/O2. 3101282   7.9250   NaN        S  1912-04-10 09:55:37
# 3      0            113803  53.1000  C123        S  1912-04-10 08:06:51
# 4      0            373450   8.0500   NaN        S  1912-04-10 09:10:39
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 895 entries, 0 to 894
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  895 non-null    int64
#  1   Survived     895 non-null    int64
#  2   Pclass       895 non-null    int64
#  3   Name         895 non-null    object
#  4   Sex          895 non-null    object
#  5   Age          717 non-null    object
#  6   SibSp        895 non-null    int64
#  7   Parch        895 non-null    int64
#  8   Ticket       895 non-null    object
#  9   Fare         895 non-null    float64
#  10  Cabin        206 non-null    object
#  11  Embarked     893 non-null    object
#  12  OnboardTime  895 non-null    object
#  13  Unnamed: 13  0 non-null      float64
# dtypes: float64(2), int64(5), object(7)
# memory usage: 98.0+ KB

# %% [markdown]
# ###Task# 2
#
# Drop any unused or unnecessary column.

# %%
titanic.drop(columns = 'Unnamed: 13', inplace = True)
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   -      1
# 2                             Heikkinen, Miss. Laina  female  26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  na      1
# 4                           Allen, Mr. William Henry    male  35      0
#
#    Parch            Ticket     Fare Cabin Embarked          OnboardTime
# 0      0         A/5 21171   7.2500   NaN        S  1912-04-10 09:42:47
# 1      0          PC 17599  71.2833   C85        C  1912-04-10 09:54:01
# 2      0  STON/O2. 3101282   7.9250   NaN        S  1912-04-10 09:55:37
# 3      0            113803  53.1000  C123        S  1912-04-10 08:06:51
# 4      0            373450   8.0500   NaN        S  1912-04-10 09:10:39

# %% [markdown]
# ###Task# 3
#
# a. Identify duplicate records
#
# b. Remove duplicate records

# %%
titanic[titanic.duplicated()]
# Out:
#     PassengerId  Survived  Pclass  \
# 18           12         1       1
# 29           12         1       1
# 62           54         1       2
# 97           81         0       3
#
#                                                  Name     Sex Age  SibSp  \
# 18                           Bonnell, Miss. Elizabeth  female  58      0
# 29                           Bonnell, Miss. Elizabeth  female  58      0
# 62  Faunthorpe, Mrs. Lizzie (Elizabeth Anne Wilkin...  female  29      1
# 97                               Waelens, Mr. Achille    male  22      0
#
#     Parch  Ticket   Fare Cabin Embarked          OnboardTime
# 18      0  113783  26.55  C103        S  1912-04-10 08:40:38
# 29      0  113783  26.55  C103        S  1912-04-10 08:40:38
# 62      0    2926  26.00   NaN        S  1912-04-10 09:32:51
# 97      0  345767   9.00   NaN        S  1912-04-10 09:38:42

# %%
titanic = titanic.drop_duplicates(keep='first')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 890          887         0       2
# 891          888         1       1
# 892          889         0       3
# 893          890         1       1
# 894          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female    -      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   na      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# 890                              Montvila, Rev. Juozas    male   27      0
# 891                       Graham, Miss. Margaret Edith  female   19      0
# 892           Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1
# 893                              Behr, Mr. Karl Howell    male   26      0
# 894                                Dooley, Mr. Patrick    male   32      0
#
#      Parch            Ticket     Fare Cabin Embarked          OnboardTime
# 0        0         A/5 21171   7.2500   NaN        S  1912-04-10 09:42:47
# 1        0          PC 17599  71.2833   C85        C  1912-04-10 09:54:01
# 2        0  STON/O2. 3101282   7.9250   NaN        S  1912-04-10 09:55:37
# 3        0            113803  53.1000  C123        S  1912-04-10 08:06:51
# 4        0            373450   8.0500   NaN        S  1912-04-10 09:10:39
# ..     ...               ...      ...   ...      ...                  ...
# 890      0            211536  13.0000   NaN        S  1912-04-10 08:36:53
# 891      0            112053  30.0000   B42        S  1912-04-10 09:00:05
# 892      2        W./C. 6607  23.4500   NaN        S  1912-04-10 09:11:02
# 893      0            111369  30.0000  C148        C  1912-04-10 09:13:39
# 894      0            370376   7.7500   NaN        Q  1912-04-10 08:26:59
#
# [891 rows x 13 columns]

# %% [markdown]
# ###Task# 4
#
# a. Preview the distint categories in gender column.
#
# b. Do you find something odd?

# %%
titanic['Sex'].unique()
# Out:
# array(['male', 'female', 'm', 'm ', 'M', 'F', 'f'], dtype=object)

# %% [markdown]
# ###Task# 5
#
# a. Map the gender labels to two unique categories 'male', 'female'

# %%
titanic['Sex'] = titanic['Sex'].map({
    'male': 'Male',
    'female': 'Female',
    'm': 'Male',
    'f': 'Female',
    'm ': 'Male',
    'F': 'Female',
    'M': 'Male'
})

# %%
titanic['Sex'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ###Task# 7
#
# a. Preview first 20 records in the 'Age' column.
#
# b. Do you observe any NaN values?

# %%
titanic['Age'].head(20)
# Out:
# 0      22
# 1       -
# 2      26
# 3      na
# 4      35
# 5     NaN
# 6      54
# 7       2
# 8     NaN
# 9      14
# 10      4
# 11     58
# 12     20
# 13     39
# 14     14
# 15     55
# 16      2
# 17    NaN
# 19     31
# 20    NaN
# Name: Age, dtype: object

# %%
titanic[titanic['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 8              9         1       3
# 17            18         1       2
# 20            20         1       3
# 27            27         0       3
# ..           ...       ...     ...
# 863          860         0       3
# 867          864         0       3
# 872          869         0       3
# 882          879         0       3
# 892          889         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 5                                     Moran, Mr. James    Male  NaN      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  Female  NaN      0
# 17                        Williams, Mr. Charles Eugene    Male  NaN      0
# 20                             Masselmani, Mrs. Fatima  Female  NaN      0
# 27                             Emir, Mr. Farred Chehab    Male  NaN      0
# ..                                                 ...     ...  ...    ...
# 863                                   Razi, Mr. Raihed    Male  NaN      0
# 867                  Sage, Miss. Dorothy Edith "Dolly"  Female  NaN      8
# 872                        van Melkebeke, Mr. Philemon    Male  NaN      0
# 882                                 Laleff, Mr. Kristo    Male  NaN      0
# 892           Johnston, Miss. Catherine Helen "Carrie"  Female  NaN      1
#
#      Parch      Ticket     Fare Cabin Embarked          OnboardTime
# 5        0      330877   8.4583   NaN        Q  1912-04-10 09:33:35
# 8        2      347742  11.1333   NaN        S  1912-04-10 08:01:26
# 17       0      244373  13.0000   NaN        S  1912-04-10 08:53:42
# 20       0        2649   7.2250   NaN        C  1912-04-10 09:32:07
# 27       0        2631   7.2250   NaN        C  1912-04-10 08:20:58
# ..     ...         ...      ...   ...      ...                  ...
# 863      0        2629   7.2292   NaN        C  1912-04-10 09:22:57
# 867      2    CA. 2343  69.5500   NaN        S  1912-04-10 09:13:12
# 872      0      345777   9.5000   NaN        S  1912-04-10 09:40:05
# 882      0      349217   7.8958   NaN        S  1912-04-10 09:07:31
# 892      2  W./C. 6607  23.4500   NaN        S  1912-04-10 09:11:02
#
# [178 rows x 13 columns]

# %% [markdown]
# ###Task# 8
#
# a. Display the count of NaN in 'Age' column.
#
# b. Replace NaN values with null values.

# %%
titanic['Age'] = titanic['Age'].replace('-', np.NaN)
titanic['Age'] = titanic['Age'].replace('na', np.NaN)
titanic['Age']
# Out:
# 0       22
# 1      NaN
# 2       26
# 3      NaN
# 4       35
#       ...
# 890     27
# 891     19
# 892    NaN
# 893     26
# 894     32
# Name: Age, Length: 891, dtype: object

# %%
titanic[titanic['Age'].isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 5              6         0       3
# 8              9         1       3
# 17            18         1       2
# ..           ...       ...     ...
# 863          860         0       3
# 867          864         0       3
# 872          869         0       3
# 882          879         0       3
# 892          889         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  NaN      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  NaN      1
# 5                                     Moran, Mr. James    Male  NaN      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  Female  NaN      0
# 17                        Williams, Mr. Charles Eugene    Male  NaN      0
# ..                                                 ...     ...  ...    ...
# 863                                   Razi, Mr. Raihed    Male  NaN      0
# 867                  Sage, Miss. Dorothy Edith "Dolly"  Female  NaN      8
# 872                        van Melkebeke, Mr. Philemon    Male  NaN      0
# 882                                 Laleff, Mr. Kristo    Male  NaN      0
# 892           Johnston, Miss. Catherine Helen "Carrie"  Female  NaN      1
#
#      Parch      Ticket     Fare Cabin Embarked          OnboardTime
# 1        0    PC 17599  71.2833   C85        C  1912-04-10 09:54:01
# 3        0      113803  53.1000  C123        S  1912-04-10 08:06:51
# 5        0      330877   8.4583   NaN        Q  1912-04-10 09:33:35
# 8        2      347742  11.1333   NaN        S  1912-04-10 08:01:26
# 17       0      244373  13.0000   NaN        S  1912-04-10 08:53:42
# ..     ...         ...      ...   ...      ...                  ...
# 863      0        2629   7.2292   NaN        C  1912-04-10 09:22:57
# 867      2    CA. 2343  69.5500   NaN        S  1912-04-10 09:13:12
# 872      0      345777   9.5000   NaN        S  1912-04-10 09:40:05
# 882      0      349217   7.8958   NaN        S  1912-04-10 09:07:31
# 892      2  W./C. 6607  23.4500   NaN        S  1912-04-10 09:11:02
#
# [180 rows x 13 columns]

# %% [markdown]
# ###Task# 9
#
# a. Treat null values by imputing a mean values.
#
# b. Treat null values by imputing a median values.
#
# c. What do you observe between two different measures of imputation?

# %%
#titanic['Age'] = titanic['Age'].fillna(titanic['Age'].mean())
#titanic['Age']

# %%
titanic['Age'] = titanic['Age'].fillna(titanic['Age'].median())
titanic['Age']
# Out:
# 0        22
# 1      28.0
# 2        26
# 3      28.0
# 4        35
#        ...
# 890      27
# 891      19
# 892    28.0
# 893      26
# 894      32
# Name: Age, Length: 891, dtype: object

# %% [markdown]
# ## Outlier Detection

# %% [markdown]
# Task# 10
#
# a. Create a box plot on 'Age' column.
#
# b. Analyse the box plot.

# %%
#Convert to numeric
titanic['Age'] = pd.to_numeric(titanic['Age'], errors='coerce')

# %%
plt.figure(figsize=(10, 6))
plt.boxplot(titanic['Age'].dropna(), vert=False)
plt.show()

# %%
# Create a colorful box plot for the 'Age' column
plt.figure(figsize=(10, 6))
boxprops = dict(linestyle='-', linewidth=3, color='skyblue')
flierprops = dict(marker='o', markerfacecolor='green', markersize=12, linestyle='none')
medianprops = dict(linestyle='--', linewidth=2.5, color='firebrick')
meanprops = dict(marker='D', markeredgecolor='black', markerfacecolor='firebrick')

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='Age', data=titanic,vert=False, patch_artist=True,
            boxprops=boxprops, flierprops=flierprops,
            medianprops=medianprops, meanprops=meanprops)
plt.title('Box Plot of Age in Titanic Dataset')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:699: UserWarning: Setting the 'color' property will override the edgecolor or facecolor properties.
#   artists = ax.bxp(**boxplot_kws)

# %% [markdown]
# ### Task# 11
#
# a. Compute z-score to detect outlier values.
#
# b. Are the results corroborating with box-plot?

# %%
from scipy import stats

# %%
z_scores = stats.zscore(titanic['Age'])
threshold = 3
outlier_indices = np.where(np.abs(z_scores) > threshold)[0]

# %%
outlier_indices
# Out:
# array([ 96, 116, 493, 630, 672, 745, 851])

# %%
filtered_Data = titanic.drop(outlier_indices)

# %%
filtered_Data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 890          887         0       2
# 891          888         1       1
# 892          889         0       3
# 893          890         1       1
# 894          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    Male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  Female  28.0      1
# 2                               Heikkinen, Miss. Laina  Female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  Female  28.0      1
# 4                             Allen, Mr. William Henry    Male  35.0      0
# ..                                                 ...     ...   ...    ...
# 890                              Montvila, Rev. Juozas    Male  27.0      0
# 891                       Graham, Miss. Margaret Edith  Female  19.0      0
# 892           Johnston, Miss. Catherine Helen "Carrie"  Female  28.0      1
# 893                              Behr, Mr. Karl Howell    Male  26.0      0
# 894                                Dooley, Mr. Patrick    Male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked          OnboardTime
# 0        0         A/5 21171   7.2500   NaN        S  1912-04-10 09:42:47
# 1        0          PC 17599  71.2833   C85        C  1912-04-10 09:54:01
# 2        0  STON/O2. 3101282   7.9250   NaN        S  1912-04-10 09:55:37
# 3        0            113803  53.1000  C123        S  1912-04-10 08:06:51
# 4        0            373450   8.0500   NaN        S  1912-04-10 09:10:39
# ..     ...               ...      ...   ...      ...                  ...
# 890      0            211536  13.0000   NaN        S  1912-04-10 08:36:53
# 891      0            112053  30.0000   B42        S  1912-04-10 09:00:05
# 892      2        W./C. 6607  23.4500   NaN        S  1912-04-10 09:11:02
# 893      0            111369  30.0000  C148        C  1912-04-10 09:13:39
# 894      0            370376   7.7500   NaN        Q  1912-04-10 08:26:59
#
# [884 rows x 13 columns]
